# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
data=pd.read_csv(r"F:\Documents\Downloads\amazon_reviews.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 marketplace  customer_id       review_id  product_id  \
# 0           0          US     50423057  R135Q3VZ4DQN5N  B00JWXFDMG
# 1           1          US     11262325  R2N0QQ6R4T7YRY  B00W5T1H9W
# 2           2          US     27541121  R3N5JE5Y4T6W5M  B00M2L6KFY
# 3           3          US      5350721  R2I150CX5IVY9Q  B0006SW2WU
# 4           4          US     24484424  R1RM9ICOOA9MQ3  B009YPDW70
#
#    product_parent                                      product_title  \
# 0       657335467  Everbling Purple and Clear Briolette Drop Swar...
# 1        26030170  925 Sterling Silver Finish 6ct Simulated Diamo...
# 2       697845240  Sterling Silver Circle "Friends Forever" Infin...
# 3       569859289  Surgical Stainless Steel Domed 9mm Fishbone Ri...
# 4       332947422       Sterling Silver Family Pendant Necklace, 18"
#
#   product_category  star_rating  helpful_votes  total_votes vine  \
# 0          Jewelry            5              0            0    N
# 1          Jewelry            5              0            0    N
# 2          Jewelry            5              0            0    N
# 3          Jewelry            5              0            0    N
# 4          Jewelry            5              0            0    N
#
#   verified_purchase                                    review_headline  \
# 0                 Y                                          Beauties!
# 1                 N                                     Great product.
# 2                 Y  Exactly as pictured and my daughter's friend l...
# 3                 Y                                         Five Stars
# 4                 Y  ... a Mother's Day gift for my Mom and she lov...
#
#                                          review_body review_date
# 0  so beautiful even tho clearly not high end ......  2015-08-31
# 1  Great product.. I got this set for my mother, ...  2015-08-31
# 2  Exactly as pictured and my daughter's friend l...  2015-08-31
# 3  Love it. Fits great. Super comfortable and nea...  2015-08-31
# 4  Got this as a Mother's Day gift for my Mom and...  2015-08-31
#    Unnamed: 0 marketplace  customer_id       review_id  product_id  \
# 0           0          US     50423057  R135Q3VZ4DQN5N  B00JWXFDMG
# 1           1          US     11262325  R2N0QQ6R4T7YRY  B00W5T1H9W
# 2           2          US     27541121  R3N5JE5Y4T6W5M  B00M2L6KFY
# 3           3          US      5350721  R2I150CX5IVY9Q  B0006SW2WU
# 4           4          US     24484424  R1RM9ICOOA9MQ3  B009YPDW70
#
#    product_parent                                      product_title  \
# 0       657335467  Everbling Purple and Clear Briolette Drop Swar...
# 1        26030170  925 Sterling Silver Finish 6ct Simulated Diamo...
# 2       697845240  Sterling Silver Circle "Friends Forever" Infin...
# 3       569859289  Surgical Stainless Steel Domed 9mm Fishbone Ri...
# 4       332947422       Sterling Silver Family Pendant Necklace, 18"
#
#   product_category  star_rating  helpful_votes  total_votes vine  \
# 0          Jewelry            5              0            0    N
# 1          Jewelry            5              0            0    N
# 2          Jewelry            5              0            0    N
# 3          Jewelry            5              0            0    N
# 4          Jewelry            5              0            0    N
#
#   verified_purchase                                    review_headline  \
# 0                 Y                                          Beauties!
# 1                 N                                     Great product.
# 2                 Y  Exactly as pictured and my daughter's friend l...
# 3                 Y                                         Five Stars
# 4                 Y  ... a Mother's Day gift for my Mom and she lov...
#
#                                          review_body review_date
# 0  so beautiful even tho clearly not high end ......  2015-08-31
# 1  Great product.. I got this set for my mother, ...  2015-08-31
# 2  Exactly as pictured and my daughter's friend l...  2015-08-31
# 3  Love it. Fits great. Super comfortable and nea...  2015-08-31
# 4  Got this as a Mother's Day gift for my Mom and...  2015-08-31

# %%
#df=pd.read_csv('data.tsv', sep='\t', header=0, error_bad_lines=False,nrows=100000)

# %%
####Selecting only required columns
data=data[['review_body','star_rating']]

# %%
data=data.dropna()
data = data.reset_index(drop=True)
data
# Out:
#                                              review_body  star_rating
# 0      so beautiful even tho clearly not high end ......            5
# 1      Great product.. I got this set for my mother, ...            5
# 2      Exactly as pictured and my daughter's friend l...            5
# 3      Love it. Fits great. Super comfortable and nea...            5
# 4      Got this as a Mother's Day gift for my Mom and...            5
# ...                                                  ...          ...
# 99946  Delivery was quick. ...the beads are loose so ...            4
# 99947  Tiny but cute! About 1/8th of an inch wide. Th...            5
# 99948  So beautiful and stunning.  There are cheapo p...            5
# 99949  The inlay is almost holographic. Very comforta...            5
# 99950  Don't even waste your money. The backs don't f...            1
#
# [99951 rows x 2 columns]
#                                              review_body  star_rating
# 0      so beautiful even tho clearly not high end ......            5
# 1      Great product.. I got this set for my mother, ...            5
# 2      Exactly as pictured and my daughter's friend l...            5
# 3      Love it. Fits great. Super comfortable and nea...            5
# 4      Got this as a Mother's Day gift for my Mom and...            5
# ...                                                  ...          ...
# 99946  Delivery was quick. ...the beads are loose so ...            4
# 99947  Tiny but cute! About 1/8th of an inch wide. Th...            5
# 99948  So beautiful and stunning.  There are cheapo p...            5
# 99949  The inlay is almost holographic. Very comforta...            5
# 99950  Don't even waste your money. The backs don't f...            1
#
# [99951 rows x 2 columns]

# %%
#The reviews with star rating 4,5 are labelled as positive reviews and 1,2 are labelled as negative reviews. 
#Remove the reviews with star rating 3 as they are considered as neutral.

# %%
data['star_rating']=data['star_rating'].astype(int) #convert the star_rating column to int
data=data[data['star_rating']!=3]
data['label']=np.where(data['star_rating']>=4,1,0) #1-Positve,0-Negative
# Out:
# <ipython-input-8-2a731c012bdc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label']=np.where(data['star_rating']>=4,1,0) #1-Positve,0-Negative
# <ipython-input-8-2a731c012bdc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label']=np.where(data['star_rating']>=4,1,0) #1-Positve,0-Negative

# %%
##### Number of reviews by start rating

# %%
data['star_rating'].value_counts()
# Out:
# 5    62673
# 4    13923
# 1     9334
# 2     5512
# Name: star_rating, dtype: int64
# 5    62673
# 4    13923
# 1     9334
# 2     5512
# Name: star_rating, dtype: int64

# %%
##### Preprocessing

# %%
### Lower casing
data['pre_process'] = data['review_body'].apply(lambda x: ' '.join(x.lower() for x in str(x).split()))
# Out:
# <ipython-input-12-d8273eaa8528>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process'] = data['review_body'].apply(lambda x: ' '.join(x.lower() for x in str(x).split()))
# <ipython-input-12-d8273eaa8528>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process'] = data['review_body'].apply(lambda x: ' '.join(x.lower() for x in str(x).split()))

# %%
data.head()
# Out:
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter's friend l...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother's day gift for my mom and...
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter's friend l...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother's day gift for my mom and...

# %%
####Remove the HTML tags and URLs from the reviews.

# %%
from bs4 import BeautifulSoup
data['pre_process']=data['pre_process'].apply(lambda x: BeautifulSoup(x).get_text())
import re
data['pre_process']=data['pre_process'].apply(lambda x: re.sub(r'http\S+', '', x))
# Out:
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/review/creata-review?ie=utf8&asin=b010xgqugs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "http://www.amazon.com/review/creata-review?ie=utf8&asin=b010xgqugs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/create-review?ie=utf8&asin=b010xgqugs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/create-review?ie=utf8&asin=b010xgqugs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/review-your-purchases/ref=oh_aui_rev_shipment_o00_s00?_encoding=utf8&asins=b01444jlxe&channel=yacc-wr#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/review-your-purchases/ref=oh_aui_rev_shipment_o00_s00?_encoding=utf8&asins=b01444jlxe&channel=yacc-wr#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/review-your-purchases/ref=pe_259730_144232530_cm_1_img?_encoding=utf8&asins=b00mand1yw&channel=ec_sft&crauthtoken=gbyfce0y80lijky6eqjb2apfm2iizb3lihevj6oaaaadaaaaafw1ffnyyxcaaaaa&customerid=a34lf5jz8ht63a#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\VIREN ( RELIANCE )\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "https://www.amazon.com/review/review-your-purchases/ref=pe_259730_144232530_cm_1_img?_encoding=utf8&asins=b00mand1yw&channel=ec_sft&crauthtoken=gbyfce0y80lijky6eqjb2apfm2iizb3lihevj6oaaaadaaaaafw1ffnyyxcaaaaa&customerid=a34lf5jz8ht63a#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <ipython-input-15-734033289915>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: BeautifulSoup(x).get_text())
# <ipython-input-15-734033289915>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: re.sub(r'http\S+', '', x))
# <ipython-input-15-734033289915>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: BeautifulSoup(x).get_text())
# <ipython-input-15-734033289915>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: re.sub(r'http\S+', '', x))

# %%
#Perform the Contractions on the reviews.
#Example: it won’t be converted as it will not be

data.head()
# Out:
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter's friend l...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother's day gift for my mom and...
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter's friend l...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother's day gift for my mom and...

# %%
def contractions(s):
    s = re.sub(r"won't", "will not",s)
    s = re.sub(r"would't", "would not",s)
    s = re.sub(r"could't", "could not",s)
    s = re.sub(r"\'d", " would",s)
    s = re.sub(r"can\'t", "can not",s)
    s = re.sub(r"n\'t", " not", s)
    s= re.sub(r"\'re", " are", s)
    s = re.sub(r"\'s", " is", s)
    s = re.sub(r"\'ll", " will", s)
    s = re.sub(r"\'t", " not", s)
    s = re.sub(r"\'ve", " have", s)
    s = re.sub(r"\'m", " am", s)
    return s
data['pre_process']=data['pre_process'].apply(lambda x:contractions(x))
# Out:
# <ipython-input-17-dd09a085c683>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x:contractions(x))
# <ipython-input-17-dd09a085c683>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x:contractions(x))

# %%
data.head()
# Out:
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter is friend ...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother is day gift for my mom an...
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  so beautiful even tho clearly not high end ......
# 1  great product.. i got this set for my mother, ...
# 2  exactly as pictured and my daughter is friend ...
# 3  love it. fits great. super comfortable and nea...
# 4  got this as a mother is day gift for my mom an...

# %%
#Remove non-alpha characters

# %%
data['pre_process']=data['pre_process'].apply(lambda x: " ".join([re.sub('[^A-Za-z]+','', x) for x in nltk.word_tokenize(x)]))
# Out:
# <ipython-input-20-ab1d1be78d52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([re.sub('[^A-Za-z]+','', x) for x in nltk.word_tokenize(x)]))
# <ipython-input-20-ab1d1be78d52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([re.sub('[^A-Za-z]+','', x) for x in nltk.word_tokenize(x)]))

# %%
data.head(20)
# Out:
#                                           review_body  star_rating  label  \
# 0   so beautiful even tho clearly not high end ......            5      1
# 1   Great product.. I got this set for my mother, ...            5      1
# 2   Exactly as pictured and my daughter's friend l...            5      1
# 3   Love it. Fits great. Super comfortable and nea...            5      1
# 4   Got this as a Mother's Day gift for my Mom and...            5      1
# 5              I Love It Make Me Won't To Get Another            5      1
# 6                                True to size, unique            5      1
# 7   This necklace is BEAUTIFUL......is a great acc...            5      1
# 8                                        just perfect            5      1
# 9                                           Love it !            5      1
# 10  They didn't even last through the first day.  ...            1      0
# 11  This is a real nice necklace for the price.  D...            5      1
# 12  This is a very comfortable ring I would defini...            5      1
# 13                       Great quality for the price!            5      1
# 14  I like the bracelet a lot, it's really cute an...            4      1
# 15  This is pretty and versatile. I have it to wea...            5      1
# 16  Don't get this like the first time I opened th...            1      0
# 18  Bought these for my daughter, cute but bigger ...            4      1
# 19              Pretty, and very comfortable to wear!            5      1
# 20  Great ring. Looks exactly like the one Capaldi...            4      1
#
#                                           pre_process
# 0   so beautiful even tho clearly not high end  bu...
# 1   great product  i got this set for my mother  a...
# 2   exactly as pictured and my daughter is friend ...
# 3   love it  fits great  super comfortable and nea...
# 4   got this as a mother is day gift for my mom an...
# 5           i love it make me will not to get another
# 6                                true to size  unique
# 7   this necklace is beautiful  is a great accent ...
# 8                                        just perfect
# 9                                            love it
# 10  they did not even last through the first day  ...
# 11  this is a real nice necklace for the price  do...
# 12  this is a very comfortable ring i would defini...
# 13                       great quality for the price
# 14  i like the bracelet a lot  it is really cute a...
# 15  this is pretty and versatile  i have it to wea...
# 16  do not get this like the first time i opened t...
# 18  bought these for my daughter  cute but bigger ...
# 19              pretty  and very comfortable to wear
# 20  great ring  looks exactly like the one capaldi...
#                                           review_body  star_rating  label  \
# 0   so beautiful even tho clearly not high end ......            5      1
# 1   Great product.. I got this set for my mother, ...            5      1
# 2   Exactly as pictured and my daughter's friend l...            5      1
# 3   Love it. Fits great. Super comfortable and nea...            5      1
# 4   Got this as a Mother's Day gift for my Mom and...            5      1
# 5              I Love It Make Me Won't To Get Another            5      1
# 6                                True to size, unique            5      1
# 7   This necklace is BEAUTIFUL......is a great acc...            5      1
# 8                                        just perfect            5      1
# 9                                           Love it !            5      1
# 10  They didn't even last through the first day.  ...            1      0
# 11  This is a real nice necklace for the price.  D...            5      1
# 12  This is a very comfortable ring I would defini...            5      1
# 13                       Great quality for the price!            5      1
# 14  I like the bracelet a lot, it's really cute an...            4      1
# 15  This is pretty and versatile. I have it to wea...            5      1
# 16  Don't get this like the first time I opened th...            1      0
# 18  Bought these for my daughter, cute but bigger ...            4      1
# 19              Pretty, and very comfortable to wear!            5      1
# 20  Great ring. Looks exactly like the one Capaldi...            4      1
#
#                                           pre_process
# 0   so beautiful even tho clearly not high end  bu...
# 1   great product  i got this set for my mother  a...
# 2   exactly as pictured and my daughter is friend ...
# 3   love it  fits great  super comfortable and nea...
# 4   got this as a mother is day gift for my mom an...
# 5           i love it make me will not to get another
# 6                                true to size  unique
# 7   this necklace is beautiful  is a great accent ...
# 8                                        just perfect
# 9                                            love it
# 10  they did not even last through the first day  ...
# 11  this is a real nice necklace for the price  do...
# 12  this is a very comfortable ring i would defini...
# 13                       great quality for the price
# 14  i like the bracelet a lot  it is really cute a...
# 15  this is pretty and versatile  i have it to wea...
# 16  do not get this like the first time i opened t...
# 18  bought these for my daughter  cute but bigger ...
# 19              pretty  and very comfortable to wear
# 20  great ring  looks exactly like the one capaldi...

# %%
##Remove the extra spaces between the words

# %%
data['pre_process']=data['pre_process'].apply(lambda x: re.sub(' +', ' ', x))
# Out:
# <ipython-input-23-d07eb47069a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: re.sub(' +', ' ', x))
# <ipython-input-23-d07eb47069a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: re.sub(' +', ' ', x))

# %%
#### Remove stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
data['pre_process']=data['pre_process'].apply(lambda x: " ".join([x for x in x.split() if x not in stop]))
# Out:
# <ipython-input-25-2a10701066a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([x for x in x.split() if x not in stop]))
# <ipython-input-25-2a10701066a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([x for x in x.split() if x not in stop]))

# %%
data.head()
# Out:
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  beautiful even tho clearly high end super grea...
# 1  great product got set mother allergic bijoux p...
# 2  exactly pictured daughter friend loved came pa...
# 3  love fits great super comfortable neat idea fi...
# 4  got mother day gift mom loved really nice qual...
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  beautiful even tho clearly high end super grea...
# 1  great product got set mother allergic bijoux p...
# 2  exactly pictured daughter friend loved came pa...
# 3  love fits great super comfortable neat idea fi...
# 4  got mother day gift mom loved really nice qual...

# %%
#### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
data['pre_process']=data['pre_process'].apply(lambda x: " ".join([lemmatizer.lemmatize(w) for w in nltk.word_tokenize(x)]))
# Out:
# <ipython-input-28-bff4ccf8209f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([lemmatizer.lemmatize(w) for w in nltk.word_tokenize(x)]))
# <ipython-input-28-bff4ccf8209f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pre_process']=data['pre_process'].apply(lambda x: " ".join([lemmatizer.lemmatize(w) for w in nltk.word_tokenize(x)]))

# %%
data.head()
# Out:
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  beautiful even tho clearly high end super grea...
# 1  great product got set mother allergic bijou pr...
# 2  exactly pictured daughter friend loved came pa...
# 3  love fit great super comfortable neat idea fis...
# 4  got mother day gift mom loved really nice qual...
#                                          review_body  star_rating  label  \
# 0  so beautiful even tho clearly not high end ......            5      1
# 1  Great product.. I got this set for my mother, ...            5      1
# 2  Exactly as pictured and my daughter's friend l...            5      1
# 3  Love it. Fits great. Super comfortable and nea...            5      1
# 4  Got this as a Mother's Day gift for my Mom and...            5      1
#
#                                          pre_process
# 0  beautiful even tho clearly high end super grea...
# 1  great product got set mother allergic bijou pr...
# 2  exactly pictured daughter friend loved came pa...
# 3  love fit great super comfortable neat idea fis...
# 4  got mother day gift mom loved really nice qual...

# %%
###Split the Data into Training and Testing sets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train, Y_test = train_test_split(data['pre_process'], data['label'], test_size=0.25, random_state=30)
print("Train: ",X_train.shape,Y_train.shape,"Test: ",(X_test.shape,Y_test.shape))
# Out:
# Train:  (68581,) (68581,) Test:  ((22861,), (22861,))
# Train:  (68581,) (68581,) Test:  ((22861,), (22861,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train, Y_test = train_test_split(data['review_body'], data['label'], test_size=0.25, random_state=30)
print("Train: ",X_train.shape,Y_train.shape,"Test: ",(X_test.shape,Y_test.shape))
# Out:
# Train:  (68581,) (68581,) Test:  ((22861,), (22861,))
# Train:  (68581,) (68581,) Test:  ((22861,), (22861,))

# %%
####Feature extraction
##### TF-IDF vectorizer

# %%
print("TFIDF Vectorizer……")
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer= TfidfVectorizer()
tf_x_train = vectorizer.fit_transform(X_train)
tf_x_test = vectorizer.transform(X_test)
# Out:
# TFIDF Vectorizer……
# TFIDF Vectorizer……

# %%
tf_x_train
# Out:
# <68581x19426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1214884 stored elements in Compressed Sparse Row format>
# <68581x19426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1214884 stored elements in Compressed Sparse Row format>

# %%
tf_x_train
# Out:
# <68581x19426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1214884 stored elements in Compressed Sparse Row format>
# <68581x19426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1214884 stored elements in Compressed Sparse Row format>

# %%
##### using SVM algorithm

from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0)

# %%
###Fitting the Training data into model

# %%
clf.fit(tf_x_train,Y_train)
# Out:
# LinearSVC(random_state=0)
# LinearSVC(random_state=0)

# %%
###Predicting the Test data

# %%
y_test_pred=clf.predict(tf_x_test)

# %%
y_test_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])
# array([0, 1, 1, ..., 1, 1, 1])

# %%
#Analyzing the results

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test, y_test_pred,output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.8642533936651584,
#   'recall': 0.8177682633128178,
#   'f1-score': 0.8403684861817682,
#   'support': 3737},
#  '1': {'precision': 0.9647606727037517,
#   'recall': 0.9749006483999163,
#   'f1-score': 0.9698041561549066,
#   'support': 19124},
#  'accuracy': 0.9492148199991252,
#  'macro avg': {'precision': 0.914507033184455,
#   'recall': 0.8963344558563671,
#   'f1-score': 0.9050863211683373,
#   'support': 22861},
#  'weighted avg': {'precision': 0.9483311332362208,
#   'recall': 0.9492148199991252,
#   'f1-score': 0.9486458035592362,
#   'support': 22861}}
# {'0': {'precision': 0.8642533936651584,
#   'recall': 0.8177682633128178,
#   'f1-score': 0.8403684861817682,
#   'support': 3737},
#  '1': {'precision': 0.9647606727037517,
#   'recall': 0.9749006483999163,
#   'f1-score': 0.9698041561549066,
#   'support': 19124},
#  'accuracy': 0.9492148199991252,
#  'macro avg': {'precision': 0.914507033184455,
#   'recall': 0.8963344558563671,
#   'f1-score': 0.9050863211683373,
#   'support': 22861},
#  'weighted avg': {'precision': 0.9483311332362208,
#   'recall': 0.9492148199991252,
#   'f1-score': 0.9486458035592362,
#   'support': 22861}}

# %%
###### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000,solver='saga')

# %%
clf.fit(tf_x_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')
# LogisticRegression(max_iter=1000, solver='saga')

# %%
y_test_pred=clf.predict(tf_x_test)

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test, y_test_pred,output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.8911773747310175,
#   'recall': 0.7757559539737757,
#   'f1-score': 0.8294706723891273,
#   'support': 3737},
#  '1': {'precision': 0.9572623419012648,
#   'recall': 0.9814892281949383,
#   'f1-score': 0.9692244139213054,
#   'support': 19124},
#  'accuracy': 0.9478587988276979,
#  'macro avg': {'precision': 0.9242198583161412,
#   'recall': 0.878622591084357,
#   'f1-score': 0.8993475431552164,
#   'support': 22861},
#  'weighted avg': {'precision': 0.9464596857481999,
#   'recall': 0.9478587988276979,
#   'f1-score': 0.9463794057368101,
#   'support': 22861}}
# {'0': {'precision': 0.8911773747310175,
#   'recall': 0.7757559539737757,
#   'f1-score': 0.8294706723891273,
#   'support': 3737},
#  '1': {'precision': 0.9572623419012648,
#   'recall': 0.9814892281949383,
#   'f1-score': 0.9692244139213054,
#   'support': 19124},
#  'accuracy': 0.9478587988276979,
#  'macro avg': {'precision': 0.9242198583161412,
#   'recall': 0.878622591084357,
#   'f1-score': 0.8993475431552164,
#   'support': 22861},
#  'weighted avg': {'precision': 0.9464596857481999,
#   'recall': 0.9478587988276979,
#   'f1-score': 0.9463794057368101,
#   'support': 22861}}
